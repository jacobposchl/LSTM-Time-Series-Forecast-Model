# %%
import tensorflow as tf
import os
import pandas as pd
import numpy as np

# %%
zip_path = tf.keras.utils.get_file(
    origin='https://storage.googleapis.com/tensorflow/tf-keras-datasets/jena_climate_2009_2016.csv.zip',
    fname = "jena_climate_2009_2016.csv.zip",
    extract = True
)

csv_path, _ = os.path.splitext(zip_path)

# %%
df = pd.read_csv(csv_path)
df
# Out:
#                   Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  \
# 0       01.01.2009 00:10:00    996.52     -8.02    265.40        -8.90
# 1       01.01.2009 00:20:00    996.57     -8.41    265.01        -9.28
# 2       01.01.2009 00:30:00    996.53     -8.51    264.91        -9.31
# 3       01.01.2009 00:40:00    996.51     -8.31    265.12        -9.07
# 4       01.01.2009 00:50:00    996.51     -8.27    265.15        -9.04
# ...                     ...       ...       ...       ...          ...
# 420546  31.12.2016 23:20:00   1000.07     -4.05    269.10        -8.13
# 420547  31.12.2016 23:30:00    999.93     -3.35    269.81        -8.06
# 420548  31.12.2016 23:40:00    999.82     -3.16    270.01        -8.21
# 420549  31.12.2016 23:50:00    999.81     -4.23    268.94        -8.53
# 420550  01.01.2017 00:00:00    999.82     -4.82    268.36        -8.42
#
#         rh (%)  VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  \
# 0        93.30          3.33          3.11          0.22       1.94
# 1        93.40          3.23          3.02          0.21       1.89
# 2        93.90          3.21          3.01          0.20       1.88
# 3        94.20          3.26          3.07          0.19       1.92
# 4        94.10          3.27          3.08          0.19       1.92
# ...        ...           ...           ...           ...        ...
# 420546   73.10          4.52          3.30          1.22       2.06
# 420547   69.71          4.77          3.32          1.44       2.07
# 420548   67.91          4.84          3.28          1.55       2.05
# 420549   71.80          4.46          3.20          1.26       1.99
# 420550   75.70          4.27          3.23          1.04       2.01
#
#         H2OC (mmol/mol)  rho (g/m**3)  wv (m/s)  max. wv (m/s)  wd (deg)
# 0                  3.12       1307.75      1.03           1.75     152.3
# 1                  3.03       1309.80      0.72           1.50     136.1
# 2                  3.02       1310.24      0.19           0.63     171.6
# 3                  3.08       1309.19      0.34           0.50     198.0
# 4                  3.09       1309.00      0.32           0.63     214.3
# ...                 ...           ...       ...            ...       ...
# 420546             3.30       1292.98      0.67           1.52     240.0
# 420547             3.32       1289.44      1.14           1.92     234.3
# 420548             3.28       1288.39      1.08           2.00     215.2
# 420549             3.20       1293.56      1.49           2.16     225.8
# 420550             3.23       1296.38      1.23           1.96     184.9
#
# [420551 rows x 15 columns]

# %%
df.index = pd.to_datetime(df['Date Time'], format='%d.%m.%Y %H:%M:%S')
df[:26]
# Out:
#                                Date Time  p (mbar)  T (degC)  Tpot (K)  \
# Date Time
# 2009-01-01 00:10:00  01.01.2009 00:10:00    996.52     -8.02    265.40
# 2009-01-01 00:20:00  01.01.2009 00:20:00    996.57     -8.41    265.01
# 2009-01-01 00:30:00  01.01.2009 00:30:00    996.53     -8.51    264.91
# 2009-01-01 01:20:00      0.19           0.50     118.6
# 2009-01-01 01:30:00      0.28           0.75     188.5
# 2009-01-01 01:40:00      0.59           0.88     185.0
# 2009-01-01 01:50:00      0.45           0.88     183.2
# 2009-01-01 02:00:00      0.25           0.63     190.3
# 2009-01-01 02:10:00      0.16           0.50     158.3
# 2009-01-01 02:20:00      0.36           0.63     184.8
# 2009-01-01 02:30:00      0.33           0.75     155.9
# 2009-01-01 02:40:00      0.07           0.50     272.4
# 2009-01-01 02:50:00      0.32           0.63     219.2
# 2009-01-01 03:00:00      0.18           0.63     167.2
# 2009-01-01 03:10:00      0.07           0.25     129.3
# 2009-01-01 03:20:00      0.10           0.63     115.3
# 2009-01-01 03:30:00      0.30           0.75     149.3
# 2009-01-01 03:40:00      0.29           0.75     149.7
# 2009-01-01 03:50:00      0.12           0.63     231.7
# 2009-01-01 04:00:00      0.10           0.38     240.0
# 2009-01-01 04:10:00      0.10           0.38     203.9
# 2009-01-01 04:20:00      0.34           0.75     159.7

# %%
temp = df["T (degC)"]
temp.plot()
# Out:
# <Axes: xlabel='Date Time'>

# %%
# [[[1], [2], [3], [4], [5]]] [6]
# [[[2], [3], [4], [5], [6]]] [7]
# [[[3], [4], [5], [6], [7]]] [8]

def df_to_X_y(df, window_size=5):
  df_as_np = df.to_numpy()
  X = []
  y = []
  for i in range(len(df_as_np)-window_size):
    row = [[a] for a in df_as_np[i:i+window_size]]
    X.append(row)
    label = df_as_np[i+window_size]
    y.append(label)
  return np.array(X), np.array(y)

# %%
WINDOW_SIZE = 5
X1, y1 = df_to_X_y(temp, WINDOW_SIZE)
X1.shape, y1.shape
# Out:
# ((420546, 5, 1), (420546,))

# %%
#Splitting data into train and test

X_train1, y_train1 = X1[:60000], y1[:60000]
X_val1, y_val1 = X1[60000:65000], y1[60000:65000]
X_test1, y_test1 = X1[65000:], y1[65000:]
X_train1.shape, y_train1.shape, X_val1.shape, y_val1.shape, X_test1.shape, y_test1.shape
# Out:
# ((60000, 5, 1), (60000,), (5000, 5, 1), (5000,), (355546, 5, 1), (355546,))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

model1 = Sequential()
model1.add(InputLayer((5, 1)))
model1.add(LSTM(64))
model1.add(Dense(8, 'relu'))
model1.add(Dense(1, 'linear'))

model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 64)                16896
#
#  dense (Dense)               (None, 8)                 520
#
#  dense_1 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 17425 (68.07 KB)
# Trainable params: 17425 (68.07 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
cp1 = ModelCheckpoint('model1/', save_best_only=True)
model1.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
#train model -> 10 epochs

model1.fit(X_train1, y_train1, validation_data=(X_val1, y_val1), epochs=10, callbacks=[cp1])
# Out:
# Epoch 1/10
# 1863/1875 [============================>.] - ETA: 0s - loss: 64.5306 - root_mean_squared_error: 8.0331INFO:tensorflow:Assets written to: model1\assets
# INFO:tensorflow:Assets written to: model1\assets
# 1875/1875 [==============================] - 10s 5ms/step - loss: 64.2467 - root_mean_squared_error: 8.0154 - val_loss: 2.9792 - val_root_mean_squared_error: 1.7260
# Epoch 2/10
# 1867/1875 [============================>.] - ETA: 0s - loss: 10.0081 - root_mean_squared_error: 3.1636INFO:tensorflow:Assets written to: model1\assets
# INFO:tensorflow:Assets written to: model1\assets
# 1875/1875 [==============================] - 8s 4ms/step - loss: 9.9804 - root_mean_squared_error: 3.1592 - val_loss: 0.3087 - val_root_mean_squared_error: 0.5556
# Epoch 3/10
# 1857/1875 [============================>.] - ETA: 0s - loss: 1.7619 - root_mean_squared_error: 1.3274INFO:tensorflow:Assets written to: model1\assets
# INFO:tensorflow:Assets written to: model1\assets
# 1875/1875 [==============================] - 7s 4ms/step - loss: 1.7516 - root_mean_squared_error: 1.3235 - val_loss: 0.1127 - val_root_mean_squared_error: 0.3356
# Epoch 4/10
# 1871/1875 [============================>.] - ETA: 0s - loss: 0.3947 - root_mean_squared_error: 0.6282INFO:tensorflow:Assets written to: model1\assets
# INFO:tensorflow:Assets written to: model1\assets
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3942 - root_mean_squared_error: 0.6278 - val_loss: 0.0770 - val_root_mean_squared_error: 0.2775
# Epoch 5/10
# 1862/1875 [============================>.] - ETA: 0s - loss: 0.1376 - root_mean_squared_error: 0.3709INFO:tensorflow:Assets written to: model1\assets
# INFO:tensorflow:Assets written to: model1\assets
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1370 - root_mean_squared_error: 0.3701 - val_loss: 0.0656 - val_root_mean_squared_error: 0.2561
# Epoch 6/10
# 1872/1875 [============================>.] - ETA: 0s - loss: 0.0792 - root_mean_squared_error: 0.2814INFO:tensorflow:Assets written to: model1\assets
# INFO:tensorflow:Assets written to: model1\assets
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0791 - root_mean_squared_error: 0.2813 - val_loss: 0.0546 - val_root_mean_squared_error: 0.2336
# Epoch 7/10
# 1875/1875 [==============================] - ETA: 0s - loss: 0.0606 - root_mean_squared_error: 0.2462INFO:tensorflow:Assets written to: model1\assets
# INFO:tensorflow:Assets written to: model1\assets
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0606 - root_mean_squared_error: 0.2462 - val_loss: 0.0516 - val_root_mean_squared_error: 0.2273
# Epoch 8/10
# 1854/1875 [============================>.] - ETA: 0s - loss: 0.0529 - root_mean_squared_error: 0.2299INFO:tensorflow:Assets written to: model1\assets
# INFO:tensorflow:Assets written to: model1\assets
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0529 - root_mean_squared_error: 0.2300 - val_loss: 0.0492 - val_root_mean_squared_error: 0.2218
# Epoch 9/10
# 1868/1875 [============================>.] - ETA: 0s - loss: 0.0491 - root_mean_squared_error: 0.2217INFO:tensorflow:Assets written to: model1\assets
# INFO:tensorflow:Assets written to: model1\assets
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0492 - root_mean_squared_error: 0.2218 - val_loss: 0.0480 - val_root_mean_squared_error: 0.2192
# Epoch 10/10
# 1870/1875 [============================>.] - ETA: 0s - loss: 0.0471 - root_mean_squared_error: 0.2170INFO:tensorflow:Assets written to: model1\assets
# INFO:tensorflow:Assets written to: model1\assets
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0470 - root_mean_squared_error: 0.2169 - val_loss: 0.0456 - val_root_mean_squared_error: 0.2135

# %%
from tensorflow.keras.models import load_model
model1 = load_model('model1/')

# %%
train_predictions = model1.predict(X_train1).flatten()
train_results = pd.DataFrame(data={'Train Predictions':train_predictions, 'Actuals':y_train1})
train_results
# Out:
# 1875/1875 [==============================] - 3s 1ms/step
#        Train Predictions  Actuals
# 0              -8.219329    -8.05
# 1              -7.964596    -7.62
# 2              -7.500032    -7.62
# 3              -7.387926    -7.91
# 4              -7.727748    -8.43
# ...                  ...      ...
# 59995           1.758334     1.82
# 59996           1.784298     1.88
# 59997           1.866460     1.74
# 59998           1.673732     1.64
# 59999           1.576659     1.60
#
# [60000 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
plt.plot(train_results['Train Predictions'][50:100])
plt.plot(train_results['Actuals'][50:100])

# %%
val_predictions = model1.predict(X_val1).flatten()
val_results = pd.DataFrame(data={'Val Predictions':val_predictions, 'Actuals':y_val1})
val_results
# Out:
# 157/157 [==============================] - 1s 2ms/step
#       Val Predictions  Actuals
# 0            1.548559     1.57
# 1            1.522370     1.49
# 2            1.433007     1.38
# 3            1.313363     1.26
# 4            1.187981     1.20
# ...               ...      ...
# 4995         8.559148     8.78
# 4996         8.997299     8.91
# 4997         8.975848     8.98
# 4998         9.032691     9.19
# 4999         9.339501     8.99
#
# [5000 rows x 2 columns]

# %%
plt.plot(val_results['Val Predictions'][:100])
plt.plot(val_results['Actuals'][:100])

# %%
test_predictions = model1.predict(X_test1).flatten()
test_results = pd.DataFrame(data={'Test Predictions':test_predictions, 'Actuals':y_test1})
test_results
# Out:
# 11111/11111 [==============================] - 18s 2ms/step
#         Test Predictions  Actuals
# 0               8.858253     9.07
# 1               9.142713     9.11
# 2               9.129174     8.88
# 3               8.719086     8.76
# 4               8.710182     8.92
# ...                  ...      ...
# 355541         -3.780169    -4.05
# 355542         -3.961513    -3.35
# 355543         -3.338331    -3.16
# 355544         -3.007362    -4.23
# 355545         -4.042407    -4.82
#
# [355546 rows x 2 columns]

# %%
plt.plot(test_results['Test Predictions'][:100])
plt.plot(test_results['Actuals'][:100])

# %%
#testing the model of test data

from sklearn.metrics import mean_squared_error as mse

def plot_predictions1(model, X, y, start=0, end=100):
  predictions = model.predict(X).flatten()
  df = pd.DataFrame(data={'Predictions': predictions, 'Actuals':y})
  plt.plot(df['Predictions'][start:end])
  plt.plot(df['Actuals'][start:end])
  return df, mse(predictions, y)

# %%
plot_predictions1(model1, X_test1, y_test1)
# Out:
# 11111/11111 [==============================] - 16s 1ms/step
# (        Predictions  Actuals
#  0          8.858253     9.07
#  1          9.142713     9.11
#  2          9.129174     8.88
#  3          8.719086     8.76
#  4          8.710182     8.92
#  ...             ...      ...
#  355541    -3.780169    -4.05
#  355542    -3.961513    -3.35
#  355543    -3.338331    -3.16
#  355544    -3.007362    -4.23
#  355545    -4.042407    -4.82
#
#  [355546 rows x 2 columns],
#  0.06406624633956699)

# %%
#creating another model -> model2

model2 = Sequential()
model2.add(InputLayer((5, 1)))
model2.add(Conv1D(64, kernel_size=2, activation='relu'))
model2.add(Flatten())
model2.add(Dense(8, 'relu'))
model2.add(Dense(1, 'linear'))
model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 4, 64)             192
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense_2 (Dense)             (None, 8)                 2056
#
#  dense_3 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 2257 (8.82 KB)
# Trainable params: 2257 (8.82 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
cp2 = ModelCheckpoint('model2/', save_best_only=True)
model2.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
model2.fit(X_train1, y_train1, validation_data=(X_val1, y_val1), epochs=10, callbacks=[cp2])
# Out:
# Epoch 1/10
# 1864/1875 [============================>.] - ETA: 0s - loss: 5.1663 - root_mean_squared_error: 2.2730INFO:tensorflow:Assets written to: model2\assets
# INFO:tensorflow:Assets written to: model2\assets
# 1875/1875 [==============================] - 3s 2ms/step - loss: 5.1376 - root_mean_squared_error: 2.2666 - val_loss: 0.3464 - val_root_mean_squared_error: 0.5886
# Epoch 2/10
# 1826/1875 [============================>.] - ETA: 0s - loss: 0.2579 - root_mean_squared_error: 0.5078INFO:tensorflow:Assets written to: model2\assets
# INFO:tensorflow:Assets written to: model2\assets
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2566 - root_mean_squared_error: 0.5066 - val_loss: 0.2432 - val_root_mean_squared_error: 0.4932
# Epoch 3/10
# 1875/1875 [==============================] - ETA: 0s - loss: 0.1735 - root_mean_squared_error: 0.4166INFO:tensorflow:Assets written to: model2\assets
# INFO:tensorflow:Assets written to: model2\assets
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1735 - root_mean_squared_error: 0.4166 - val_loss: 0.1553 - val_root_mean_squared_error: 0.3941
# Epoch 4/10
# 1826/1875 [============================>.] - ETA: 0s - loss: 0.1104 - root_mean_squared_error: 0.3322INFO:tensorflow:Assets written to: model2\assets
# INFO:tensorflow:Assets written to: model2\assets
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1098 - root_mean_squared_error: 0.3314 - val_loss: 0.0998 - val_root_mean_squared_error: 0.3159
# Epoch 5/10
# 1839/1875 [============================>.] - ETA: 0s - loss: 0.0816 - root_mean_squared_error: 0.2856INFO:tensorflow:Assets written to: model2\assets
# INFO:tensorflow:Assets written to: model2\assets
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0815 - root_mean_squared_error: 0.2855 - val_loss: 0.0803 - val_root_mean_squared_error: 0.2833
# Epoch 6/10
# 1818/1875 [============================>.] - ETA: 0s - loss: 0.0710 - root_mean_squared_error: 0.2665INFO:tensorflow:Assets written to: model2\assets
# INFO:tensorflow:Assets written to: model2\assets
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0706 - root_mean_squared_error: 0.2657 - val_loss: 0.0725 - val_root_mean_squared_error: 0.2693
# Epoch 7/10
# 1825/1875 [============================>.] - ETA: 0s - loss: 0.0642 - root_mean_squared_error: 0.2534INFO:tensorflow:Assets written to: model2\assets
# INFO:tensorflow:Assets written to: model2\assets
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0642 - root_mean_squared_error: 0.2534 - val_loss: 0.0663 - val_root_mean_squared_error: 0.2575
# Epoch 8/10
# 1850/1875 [============================>.] - ETA: 0s - loss: 0.0586 - root_mean_squared_error: 0.2422INFO:tensorflow:Assets written to: model2\assets
# INFO:tensorflow:Assets written to: model2\assets
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0586 - root_mean_squared_error: 0.2420 - val_loss: 0.0625 - val_root_mean_squared_error: 0.2500
# Epoch 9/10
# 1860/1875 [============================>.] - ETA: 0s - loss: 0.0536 - root_mean_squared_error: 0.2315INFO:tensorflow:Assets written to: model2\assets
# INFO:tensorflow:Assets written to: model2\assets
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0535 - root_mean_squared_error: 0.2313 - val_loss: 0.0534 - val_root_mean_squared_error: 0.2312
# Epoch 10/10
# 1820/1875 [============================>.] - ETA: 0s - loss: 0.0498 - root_mean_squared_error: 0.2231INFO:tensorflow:Assets written to: model2\assets
# INFO:tensorflow:Assets written to: model2\assets
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0496 - root_mean_squared_error: 0.2227 - val_loss: 0.0505 - val_root_mean_squared_error: 0.2246

# %%
plot_predictions1(model2, X_test1, y_test1)
# Out:
# 11111/11111 [==============================] - 9s 775us/step
# (        Predictions  Actuals
#  0          9.021326     9.07
#  1          9.106156     9.11
#  2          9.145588     8.88
#  3          8.843531     8.76
#  4          8.732985     8.92
#  ...             ...      ...
#  355541    -3.882786    -4.05
#  355542    -4.062197    -3.35
#  355543    -3.315578    -3.16
#  355544    -3.030339    -4.23
#  355545    -4.265280    -4.82
#
#  [355546 rows x 2 columns],
#  0.0486763661214622)

# %%
#creates model 3 

model3 = Sequential()
model3.add(InputLayer((5, 1)))
model3.add(GRU(64))
model3.add(Dense(8, 'relu'))
model3.add(Dense(1, 'linear'))
model3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 64)                12864
#
#  dense_4 (Dense)             (None, 8)                 520
#
#  dense_5 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 13393 (52.32 KB)
# Trainable params: 13393 (52.32 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
cp3 = ModelCheckpoint('model3/', save_best_only=True)
model3.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
model3.fit(X_train1, y_train1, validation_data=(X_val1, y_val1), epochs=10, callbacks=[cp3])
# Out:
# Epoch 1/10
# 1866/1875 [============================>.] - ETA: 0s - loss: 24.9171 - root_mean_squared_error: 4.9917INFO:tensorflow:Assets written to: model3\assets
# INFO:tensorflow:Assets written to: model3\assets
# 1875/1875 [==============================] - 9s 4ms/step - loss: 24.8054 - root_mean_squared_error: 4.9805 - val_loss: 0.1505 - val_root_mean_squared_error: 0.3880
# Epoch 2/10
# 1866/1875 [============================>.] - ETA: 0s - loss: 0.5685 - root_mean_squared_error: 0.7540INFO:tensorflow:Assets written to: model3\assets
# INFO:tensorflow:Assets written to: model3\assets
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.5665 - root_mean_squared_error: 0.7526 - val_loss: 0.0932 - val_root_mean_squared_error: 0.3053
# Epoch 3/10
# 1857/1875 [============================>.] - ETA: 0s - loss: 0.1310 - root_mean_squared_error: 0.3619INFO:tensorflow:Assets written to: model3\assets
# INFO:tensorflow:Assets written to: model3\assets
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1304 - root_mean_squared_error: 0.3611 - val_loss: 0.0665 - val_root_mean_squared_error: 0.2578
# Epoch 4/10
# 1865/1875 [============================>.] - ETA: 0s - loss: 0.0728 - root_mean_squared_error: 0.2698INFO:tensorflow:Assets written to: model3\assets
# INFO:tensorflow:Assets written to: model3\assets
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0727 - root_mean_squared_error: 0.2696 - val_loss: 0.0588 - val_root_mean_squared_error: 0.2425
# Epoch 5/10
# 1871/1875 [============================>.] - ETA: 0s - loss: 0.0565 - root_mean_squared_error: 0.2377INFO:tensorflow:Assets written to: model3\assets
# INFO:tensorflow:Assets written to: model3\assets
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0565 - root_mean_squared_error: 0.2376 - val_loss: 0.0557 - val_root_mean_squared_error: 0.2361
# Epoch 6/10
# 1872/1875 [============================>.] - ETA: 0s - loss: 0.0501 - root_mean_squared_error: 0.2238INFO:tensorflow:Assets written to: model3\assets
# INFO:tensorflow:Assets written to: model3\assets
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0501 - root_mean_squared_error: 0.2238 - val_loss: 0.0513 - val_root_mean_squared_error: 0.2264
# Epoch 7/10
# 1858/1875 [============================>.] - ETA: 0s - loss: 0.0470 - root_mean_squared_error: 0.2169INFO:tensorflow:Assets written to: model3\assets
# INFO:tensorflow:Assets written to: model3\assets
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0470 - root_mean_squared_error: 0.2169 - val_loss: 0.0482 - val_root_mean_squared_error: 0.2195
# Epoch 8/10
# 1869/1875 [============================>.] - ETA: 0s - loss: 0.0455 - root_mean_squared_error: 0.2132INFO:tensorflow:Assets written to: model3\assets
# INFO:tensorflow:Assets written to: model3\assets
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0454 - root_mean_squared_error: 0.2131 - val_loss: 0.0471 - val_root_mean_squared_error: 0.2169
# Epoch 9/10
# 1873/1875 [============================>.] - ETA: 0s - loss: 0.0442 - root_mean_squared_error: 0.2103INFO:tensorflow:Assets written to: model3\assets
# INFO:tensorflow:Assets written to: model3\assets
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0442 - root_mean_squared_error: 0.2103 - val_loss: 0.0465 - val_root_mean_squared_error: 0.2157
# Epoch 10/10
# 1875/1875 [==============================] - ETA: 0s - loss: 0.0434 - root_mean_squared_error: 0.2084INFO:tensorflow:Assets written to: model3\assets
# INFO:tensorflow:Assets written to: model3\assets
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0434 - root_mean_squared_error: 0.2084 - val_loss: 0.0453 - val_root_mean_squared_error: 0.2128

# %%
plot_predictions1(model3, X_test1, y_test1)
# Out:
# 11111/11111 [==============================] - 17s 2ms/step
# (        Predictions  Actuals
#  0          8.885626     9.07
#  1          9.175942     9.11
#  2          9.134630     8.88
#  3          8.765526     8.76
#  4          8.743918     8.92
#  ...             ...      ...
#  355541    -3.911973    -4.05
#  355542    -4.105124    -3.35
#  355543    -3.075986    -3.16
#  355544    -2.950057    -4.23
#  355545    -4.567918    -4.82
#
#  [355546 rows x 2 columns],
#  0.05263995840312775)

# %%
plot_predictions1(model1, X_test1, y_test1)
plot_predictions1(model2, X_test1, y_test1)
plot_predictions1(model3, X_test1, y_test1)
# Out:
# 11111/11111 [==============================] - 15s 1ms/step
#  6336/11111 [================>.............] - ETA: 3s
